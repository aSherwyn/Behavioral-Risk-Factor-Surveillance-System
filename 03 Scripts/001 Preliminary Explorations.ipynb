# %% [markdown]
# # 001 Preliminary Explorations
# A series of queries to get acquainted with the data set.
# 1. Imports and display options
# 2. Basic set information
# 3. Frequency counts of columns
# 4. Break-out inquiries

# %% [markdown]
# ## 1. Imports and display options

# %%
import pandas as pd
import numpy as np
import os

# %%
#Creating a path to the root directory for this project
path = r'C:\Users\theva\OneDrive\CareerFoundry\Data Immersion\A6\BRFSS'

# %% [markdown]
# Note: Orginal data obtained from CDC.gov on 12/14/2022. https://chronicdata.cdc.gov/Behavioral-Risk-Factors/Behavioral-Risk-Factor-Surveillance-System-BRFSS-P/dttw-5yxu

# %%
#Importing products.csv to df_prods
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'Behavioral_Risk_Factor_Surveillance_System__BRFSS__Prevalence_Data__2011_to_present_.csv'))
# Out:
# C:\Users\theva\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
pd.set_option('display.max_rows', 200)

# %% [markdown]
# ## 2. Basic set information

# %%
df.head()
# Out:
#    Year Locationabbr Locationdesc                      Class       Topic  \
# 0  2012           GU         Guam               Demographics         Age
# 1  2012           GU         Guam               Demographics         Age
# 2  2020           AL      Alabama  Chronic Health Indicators  Depression
# 3  2020           AL      Alabama  Chronic Health Indicators    Diabetes
# 4  2020           AL      Alabama  Chronic Health Indicators    Diabetes
#
#                                             Question  \
# 0                                  What is your age?
# 1                                  What is your age?
# 2  Ever told you that you have a form of depression?
# 3  Have you ever been told by a doctor that you h...
# 4  Have you ever been told by a doctor that you h...
#
#                                   Response            Break_Out  \
# 0                              55-64 years              Overall
# 1                              35-44 years               Female
# ...

# %%
df.tail()
# Out:
#          Year Locationabbr    Locationdesc                      Class  \
# 2289897  2021           PR     Puerto Rico      Cholesterol Awareness
# 2289898  2021           VI  Virgin Islands               Demographics
# 2289899  2021           VI  Virgin Islands               Demographics
# 2289900  2021           PR     Puerto Rico               Demographics
# 2289901  2021           VI  Virgin Islands  Chronic Health Indicators
#
#                       Topic  \
# 2289897    Cholesterol High
# 2289898  Number of Children
# 2289899  Number of Children
# 2289900              Income
# 2289901          Depression
#
#                                                   Question  \
# 2289897  Adults who have had their blood cholesterol ch...
# 2289898  How many children live in your household? (var...
# 2289899  How many children live in your household? (var...
# 2289900              What is your annual household income?
# 2289901  Ever told you that you have a form of depression?
#
# ...

# %%
df.shape
# Out:
# (2289902, 27)

# %%
df.columns
# Out:
# Index(['Year', 'Locationabbr', 'Locationdesc', 'Class', 'Topic', 'Question',
#        'Response', 'Break_Out', 'Break_Out_Category', 'Sample_Size',
#        'Data_value', 'Confidence_limit_Low', 'Confidence_limit_High',
#        'Display_order', 'Data_value_unit', 'Data_value_type',
#        'Data_Value_Footnote_Symbol', 'Data_Value_Footnote', 'DataSource',
#        'ClassId', 'TopicId', 'LocationID', 'BreakoutID', 'BreakOutCategoryID',
#        'QuestionID', 'ResponseID', 'GeoLocation'],
#       dtype='object')

# %% [markdown]
# ## 3. Frequency counts of columns

# %%
df['Year'].value_counts().sort_index()
# Out:
# 2011    145364
# 2012    148824
# 2013    202751
# 2014    194798
# 2015    230101
# 2016    229714
# 2017    235303
# 2018    217579
# 2019    223058
# 2020    220975
# 2021    241435
# Name: Year, dtype: int64

# %%
df['Locationabbr'].value_counts().sort_index()
# Out:
# AK    43150
# AL    43161
# AR    43106
# AZ    43122
# CA    43178
# CO    43169
# CT    43099
# DC    43120
# DE    43147
# FL    38626
# GA    43168
# GU    43081
# HI    43167
# IA    43155
# ID    43104
# IL    43150
# IN    43167
# KS    43179
# KY    43171
# LA    43171
# MA    43180
# MD    43125
# ME    43134
# MI    43176
# MN    43177
# MO    43164
# MS    43125
# MT    43131
# NC    43174
# ND    43081
# NE    43183
# NH    43080
# NJ    38892
# NM    43161
# NV    43160
# NY    43158
# OH    43176
# OK    43178
# OR    43143
# PA    43171
# PR    42675
# RI    43093
# SC    43181
# SD    43147
# TN    43146
# TX    43174
# US     1792
# UT    43173
# UW     1792
# VA    43168
# VI     8804
# VT    43056
# WA    43124
# WI    43149
# WV    43132
# WY    43136
# Name: Locationabbr, dtype: int64

# %%
df['Locationdesc'].value_counts().sort_index()
# Out:
# Alabama                                       43161
# Alaska                                        43150
# All States and DC (median) **                  1792
# All States, DC and Territories (median) **     1792
# Arizona                                       43122
# Arkansas                                      43106
# California                                    43178
# Colorado                                      43169
# Connecticut                                   43099
# Delaware                                      43147
# District of Columbia                          43120
# Florida                                       38626
# Georgia                                       43168
# Guam                                          43081
# Hawaii                                        43167
# Idaho                                         43104
# Illinois                                      43150
# Indiana                                       43167
# ...

# %%
df['Class'].value_counts().sort_index()
# Out:
# Alcohol Consumption              87881
# Cholesterol Awareness            47854
# Chronic Health Indicators       460856
# Colorectal Cancer Screening      44687
# Days of Poor Health              25320
# Demographics                    807571
# E-Cigarette Use                  25632
# Fruits and Vegetables            27284
# HIV-AIDS                         24415
# Health Care Access/Coverage     179418
# Health Status                   102514
# Hypertension Awareness           16084
# Immunization                     64091
# Injury                           35479
# Oral Health                      37474
# Overweight and Obesity (BMI)     58538
# Physical Activity                68632
# Prostate Cancer                  11932
# Tobacco Use                     124422
# Women's Health                   39818
# Name: Class, dtype: int64

# %%
df['Topic'].value_counts().sort_index()
# Out:
# Aerobic Activity            13112
# Age                         66881
# Alcohol Consumption         29296
# All Teeth Removed           11049
# Arthritis                   86147
# Asthma                      58587
# BMI Categories              58538
# Binge Drinking              29295
# Blood Stool Test            19869
# COPD                        29287
# Cardiovascular Disease     104500
# Cholesterol Checked         31770
# Cholesterol High            16084
# Colonoscopy                  4930
# Current Smoker Status       29295
# Dental Visit                13213
# Depression                  29295
# Diabetes                    58168
# Disability status          147098
# Drink and Drive             13137
# E-Cigarette Use             25632
# Education                   49259
# Employment                 116940
# Exercise                    29296
# Fair or Poor Health         29297
# Flu Shot                    24620
# Fruit Consumption           13642
# ...

# %%
df.groupby('Class')['Topic'].value_counts()
# Out:
# Class                         Topic
# Alcohol Consumption           Alcohol Consumption         29296
#                               Binge Drinking              29295
#                               Heavy Drinking              29290
# Cholesterol Awareness         Cholesterol Checked         31770
#                               Cholesterol High            16084
# Chronic Health Indicators     Cardiovascular Disease     104500
#                               Arthritis                   86147
#                               Asthma                      58587
#                               Diabetes                    58168
#                               Depression                  29295
#                               COPD                        29287
#                               Other Cancer                29287
#                               Kidney                      29269
#                               Skin Cancer                 29230
# ...

# %%
df['Question'].value_counts().sort_index()
# Out:
# About how long has it been since you last visited a doctor for a routine checkup?                                                                                                60965
# Adults aged 18-64 who have any kind of health care coverage (variable calculated from one or more BRFSS questions)                                                               28127
# Adults aged 50+ who have ever had a sigmoidoscopy or colonoscopy (variable calculated from one or more BRFSS questions)                                                           4244
# Adults aged 50+ who have had a blood stool test within the past two years (variable calculated from one or more BRFSS questions)                                                  4232
# Adults aged 50-75 who have had a blood stool test within the past year (variable calculated from one or more BRFSS questions)                                                    10707
# ...

# %%
df['Response'].value_counts().sort_index()
# Out:
# $100,000 - 199,999                                                                                 1115
# $15,000 - 24,999                                                                                  11626
# $200,000+                                                                                          1115
# $25,000 - 34,999                                                                                  11624
# $35,000 -  49,999                                                                                 11625
# $50,000 - 99,999                                                                                   1115
# $50,000+                                                                                          10510
# 1-13 days when mental health not good                                                              4220
# 1-13 days when physical health not good                                                            4220
# ...

# %%
df['Break_Out'].value_counts().sort_index()
# Out:
# $100,000-$199,999                                           8586
# $15,000-$24,999                                            91932
# $200,000+                                                   8586
# $25,000-$34,999                                            91915
# $35,000-$49,999                                            91909
# $50,000+                                                   83342
# $50,000-$99,999                                             8586
# 18-24                                                      83681
# 21-25                                                        106
# 21-30                                                        304
# 25-34                                                      83939
# 26-35                                                        106
# 31-40                                                        304
# 35-44                                                      84014
# ...

# %%
df['Break_Out_Category'].value_counts().sort_index()
# Out:
# Age Group             523117
# Education Attained    370480
# Gender                186525
# Household Income      476784
# Overall                98544
# Race/Ethnicity        634452
# Name: Break_Out_Category, dtype: int64

# %%
df['Sample_Size'].value_counts()
# Out:
# 0         47741
# 1         38327
# 2         32285
# 3         28648
# 4         25961
#           ...
# 13,962        1
# 13,436        1
# 14,779        1
# 8,923         1
# 11,558        1
# Name: Sample_Size, Length: 14500, dtype: int64

# %%
df['Data_value'].value_counts().sort_index()
# Out:
# 0.0        11
# 0.1        74
# 0.2       239
# 0.3       425
# 0.4       910
#          ...
# 99.6     1414
# 99.7     1182
# 99.8     1325
# 99.9      861
# 100.0    2676
# Name: Data_value, Length: 1001, dtype: int64

# %%
df['Confidence_limit_Low'].value_counts().sort_index()
# Out:
# 0.0        50
# 0.1       477
# 0.2      1763
# 0.3      2855
# 0.4      4525
#          ...
# 99.6      568
# 99.7      420
# 99.8      320
# 99.9      158
# 100.0    2492
# Name: Confidence_limit_Low, Length: 1001, dtype: int64

# %%
df['Confidence_limit_High'].value_counts().sort_index()
# Out:
# 0.0          6
# 0.1         24
# 0.2         77
# 0.3        150
# 0.4        255
#          ...
# 99.6      2869
# 99.7      2526
# 99.8      3032
# 99.9      2834
# 100.0    26856
# Name: Confidence_limit_High, Length: 1001, dtype: int64

# %%
df['Display_order'].value_counts().sort_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2364\2439588749.py in <module>
# ----> 1 df['Display_order'].value_counts().sort_index()
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in sort_index(self, axis, level, ascending, inplace, kind, na_position, sort_remaining, ignore_index, key)
#    3615         """
#    3616
# -> 3617         return super().sort_index(
#    3618             axis,
#    3619             level,
#
# ...

# %%
df['Data_value_unit'].value_counts().sort_index()
# Out:
# %    2289902
# Name: Data_value_unit, dtype: int64

# %%
df['Data_value_type'].value_counts().sort_index()
# Out:
# Crude Prevalence    2289902
# Name: Data_value_type, dtype: int64

# %%
df['Data_Value_Footnote_Symbol'].value_counts().sort_index()
# Out:
# *      376693
# **      12245
# ***     35834
# Name: Data_Value_Footnote_Symbol, dtype: int64

# %%
df['Data_Value_Footnote'].value_counts().sort_index()
# Out:
# ** Median value reported with no confidence intervals.                                                                                                                                                        338
# No responses for this data cell                                                                                                                                                                             39089
# No responses for this data cell.                                                                                                                                                                             8652
# Prevalence estimate not available if the unweighted sample size for the denominator was < 50 or the Relative Standard Error (RSE) is > 0.3 or if the state did not collect data for that calendar year.    376693
# Name: Data_Value_Footnote, dtype: int64

# %%
df['DataSource'].value_counts().sort_index()
# Out:
# BRFSS    2289902
# Name: DataSource, dtype: int64

# %%
df['ClassId'].value_counts().sort_index()
# Out:
# CLASS01     87881
# CLASS02     47854
# CLASS03    460856
# CLASS04     44687
# CLASS05    807571
# CLASS06     27284
# CLASS07    179418
# CLASS08    102514
# CLASS09     24415
# CLASS10     16084
# CLASS11     64091
# CLASS12     35479
# CLASS13     37474
# CLASS14     58538
# CLASS15     68632
# CLASS16     11932
# CLASS17    124422
# CLASS18     39818
# CLASS19     25632
# CLASS20     25320
# Name: ClassId, dtype: int64

# %%
df['TopicId'].value_counts().sort_index()
# Out:
# TOPIC01     13112
# TOPIC02     45240
# TOPIC03     19532
# TOPIC04      7052
# TOPIC05     64172
# TOPIC06     39064
# TOPIC07     19532
# TOPIC08     13523
# TOPIC09     39064
# TOPIC10     75316
# TOPIC11     19560
# TOPIC12     11200
# TOPIC14     19532
# TOPIC15     19532
# TOPIC16      8332
# TOPIC17     19532
# TOPIC18     39064
# TOPIC19    103180
# TOPIC20      8332
# TOPIC21     33128
# TOPIC22     78128
# TOPIC23     19532
# TOPIC24     19532
# TOPIC26     16564
# TOPIC27     11200
# TOPIC28     19532
# TOPIC29     19532
# TOPIC30     19532
# TOPIC31     11200
# TOPIC32     19532
# TOPIC33     41255
# TOPIC34      8332
# TOPIC35     19532
# TOPIC36     48830
# TOPIC37     15064
# TOPIC38     58596
# TOPIC39     58596
# TOPIC40     19532
# TOPIC41     48830
# TOPIC42      7612
# TOPIC43     29298
# TOPIC45     13112
# TOPIC46     16564
# TOPIC47      7692
# TOPIC48     54384
# TOPIC49     29298
# TOPIC50     13852
# TOPIC51     18260
# TOPIC52      4930
# TOPIC53     19532
# ...

# %%
df['LocationID'].value_counts().sort_index()
# Out:
# 1     43161
# 2     43150
# 4     43122
# 5     43106
# 6     43178
# 8     43169
# 9     43099
# 10    43147
# 11    43120
# 12    38626
# 13    43168
# 15    43167
# 16    43104
# 17    43150
# 18    43167
# 19    43155
# 20    43179
# 21    43171
# 22    43171
# 23    43134
# 24    43125
# 25    43180
# 26    43176
# 27    43177
# 28    43125
# 29    43164
# 30    43131
# 31    43183
# 32    43160
# 33    43080
# 34    38892
# 35    43161
# 36    43158
# 37    43174
# 38    43081
# 39    43176
# 40    43178
# 41    43143
# 42    43171
# 44    43093
# 45    43181
# 46    43147
# 47    43146
# 48    43174
# 49    43173
# 50    43056
# 51    43168
# 53    43124
# 54    43132
# 55    43149
# 56    43136
# 66    43081
# 72    42675
# 78     8804
# 98     1792
# 99     1792
# Name: LocationID, dtype: int64

# %%
df['BreakoutID'].value_counts().sort_index()
# Out:
# AGE01       83681
# AGE02       83939
# AGE03       84014
# AGE04       84028
# AGE05       84006
# AGE06        1064
# AGE07        3938
# AGE08        1912
# AGE09       84705
# AGE10        2864
# AGE11        2864
# AGE12         304
# AGE13         304
# AGE14         304
# AGE15         304
# AGE16         304
# AGE17        2026
# AGE18         426
# AGE19        1600
# AGE20         106
# AGE21         106
# AGE22         106
# AGE23         106
# AGE24         106
# BO1         98544
# EDUCA1      92608
# EDUCA2      92624
# EDUCA3      92622
# EDUCA4      92626
# INCOME01     8586
# INCOME02     8586
# INCOME03     8586
# INCOME04     8586
# INCOME05     8586
# INCOME06     8586
# INCOME07     8586
# INCOME1     83342
# INCOME2     83346
# INCOME3     83329
# INCOME4     83323
# INCOME5     83342
# RACE01      60405
# RACE02      60405
# RACE03      60405
# RACE04      60405
# RACE05      60405
# RACE06      60405
# RACE07      60405
# RACE08      60405
# RACE1       30504
# ...

# %%
df['BreakOutCategoryID'].value_counts().sort_index()
# Out:
# CAT1     98544
# CAT2    186525
# CAT3    523117
# CAT4    634452
# CAT5    370480
# CAT6    476784
# Name: BreakOutCategoryID, dtype: int64

# %%
df['QuestionID'].value_counts().sort_index()
# Out:
# ADDEPEV2    20855
# ADDEPEV3     8440
# AGE         66881
# BLIND       24412
# BLOODCHO     7644
# CHCCOPD      2442
# CHCCOPD1    18405
# CHCCOPD2     5468
# CHCCOPD3     2972
# CHCKDNY1     2760
# CHCKDNY2     8440
# CHCKIDNY    18069
# CHCOCNCR    29287
# CHCSCNCR    29230
# CHCVISN1     3423
# CHCVISON     3663
# CHECKUP1    60965
# CVDCRHD4    29258
# CVDINFR4    29265
# CVDSTRK3    29257
# DEAF        16772
# DECIDE      24413
# DIABETE3    41288
# DIABETE4    16880
# DIFFALON    24410
# DIFFDRES    24404
# DIFFWALK    24415
# DRNKANY5    29296
# ECIGNOW1     5944
# EDUCA       49259
# EMPLOY      19416
# EMPLOY1     97524
# GENHLTH     73217
# HIVTST6     15975
# HIVTST7      8440
# HLTHPLN1    26321
# INCOME      52552
# INCOME1      7805
# INTERNET    13215
# MARITAL     87757
# MEDCOST     21441
# MEDCOST1     2972
# PERSDOC2    32162
# PERSDOC3     4458
# QLACTLM2    12525
# RACE        19053
# RACE8       54384
# RENTHOM1    36619
# SEX         27176
# SHINGLE2     4559
# ...

# %%
df['ResponseID'].value_counts().sort_index()
# Out:
# RESP001     13589
# RESP002     13587
# RESP003     12208
# RESP004     12206
# RESP005      3823
# RESP006      3794
# RESP007     10622
# RESP008      3791
# RESP009     16026
# RESP010     11143
# RESP011     11146
# RESP012     11147
# RESP013     11148
# RESP014     11150
# RESP015     11147
# RESP016     11627
# RESP017     11626
# RESP018     11624
# RESP019     11625
# RESP020     10510
# RESP021     12312
# RESP022     12316
# RESP023     12315
# RESP024     12316
# RESP025      2440
# RESP026      2438
# RESP027     14621
# RESP028     14626
# RESP029      2434
# RESP030     14592
# RESP031     14537
# RESP032     14642
# RESP033     14649
# RESP034     14645
# RESP035     14562
# RESP036     14626
# RESP037     14647
# RESP038     14628
# RESP039     14648
# RESP040     14647
# RESP041     14648
# RESP042     14595
# RESP046    503629
# RESP047      2575
# RESP048      2575
# RESP049      2575
# RESP050     12208
# RESP051     14316
# RESP052     14560
# RESP053     12205
# ...

# %%
df['GeoLocation'].value_counts().sort_index()
# Out:
# (13.444304, 144.793731)                      43081
# (18.220833, -66.590149)                      42675
# (18.335765, -64.896335)                       8804
# (21.304850435, -157.857749403)               17385
# (21.304850435000446, -157.85774940299973)    25782
# (28.932040377, -81.928960539)                17393
# (28.932040377000476, -81.92896053899966)     21233
# (31.312660644, -92.445680071)                17389
# (31.31266064400046, -92.44568007099969)      25782
# (31.827240407, -99.426770206)                17392
# (31.827240407000488, -99.42677020599967)     25782
# (32.745510099, -89.538030825)                17343
# (32.745510099000455, -89.53803082499968)     25782
# (32.839681093, -83.627580346)                17386
# (32.83968109300048, -83.62758034599966)      25782
# (32.840571122, -86.631860762)                17379
# (32.84057112200048, -86.63186076199969)      25782
# (33.998821303, -81.045371207)                17399
# ...

# %% [markdown]
# ## 4. Break-out inquiries

# %% [markdown]
# #### sub1: ResponseID = RESP010

# %%
#Creating a limited group to expore the nature of the break-out variable
#sub1 is records from Ak, 2021, AGE question, RESP010
sub1 = df.loc[(df['Year'] == 2021) & (df['Locationabbr']== 'AK') & (df['QuestionID'] == 'AGE') & (df['ResponseID'] == 'RESP010')]

# %%
#Examining sub1
sub1.head(30)
# Out:
#          Year Locationabbr Locationdesc         Class Topic  \
# 2052063  2021           AK       Alaska  Demographics   Age
# 2052653  2021           AK       Alaska  Demographics   Age
# 2052690  2021           AK       Alaska  Demographics   Age
# 2052763  2021           AK       Alaska  Demographics   Age
# 2053620  2021           AK       Alaska  Demographics   Age
# 2053627  2021           AK       Alaska  Demographics   Age
# 2055288  2021           AK       Alaska  Demographics   Age
# 2055963  2021           AK       Alaska  Demographics   Age
# 2056466  2021           AK       Alaska  Demographics   Age
# 2056996  2021           AK       Alaska  Demographics   Age
# 2057883  2021           AK       Alaska  Demographics   Age
# 2058575  2021           AK       Alaska  Demographics   Age
# 2058645  2021           AK       Alaska  Demographics   Age
# 2059339  2021           AK       Alaska  Demographics   Age
# 2061284  2021           AK       Alaska  Demographics   Age
# ...

# %%
#Breakout frequency count
sub1['Break_Out'].value_counts().sort_index()
# Out:
# $100,000-$199,999                                          1
# $15,000-$24,999                                            1
# $200,000+                                                  1
# $25,000-$34,999                                            1
# $35,000-$49,999                                            1
# $50,000-$99,999                                            1
# American Indian or Alaskan Native, non-Hispanic            1
# Asian, non-Hispanic                                        1
# Black, non-Hispanic                                        1
# College graduate                                           1
# Female                                                     1
# H.S. or G.E.D.                                             1
# Hispanic                                                   1
# Less than $15,000                                          1
# Less than H.S.                                             1
# ...

# %%
#BreakOutCategoryID frequency count
sub1['Break_Out_Category'].value_counts().sort_index()
# Out:
# Education Attained    4
# Gender                2
# Household Income      7
# Overall               1
# Race/Ethnicity        8
# Name: Break_Out_Category, dtype: int64

# %%
sub1.groupby('Break_Out_Category')['Sample_Size'].value_counts()
# Out:
# Break_Out_Category  Sample_Size
# Education Attained  173            1
#                     23             1
#                     31             1
#                     75             1
# Gender              121            1
#                     182            1
# Household Income    14             1
#                     22             1
#                     28             1
#                     32             1
#                     47             1
#                     50             1
#                     7              1
# Overall             303            1
# Race/Ethnicity      4              2
#                     16             1
#                     17             1
#                     178            1
#                     33             1
#                     45             1
#                     6              1
# Name: Sample_Size, dtype: int64

# %%
sub1.Sample_Size = sub1.Sample_Size.astype(int)
# Out:
# C:\Users\theva\anaconda3\lib\site-packages\pandas\core\generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
sub1.groupby('Break_Out_Category')['Sample_Size'].sum()
# Out:
# Break_Out_Category
# Education Attained    302
# Gender                303
# Household Income      200
# Overall               303
# Race/Ethnicity        303
# Name: Sample_Size, dtype: int32

# %% [markdown]
# #### sub2: ResponseID = RESP011

# %%
#Creating a limited group to expore the nature of the break-out variable
#sub2 is records from Ak, 2021, AGE question, RESP011
sub2 = df.loc[(df['Year'] == 2021) & (df['Locationabbr']== 'AK') & (df['QuestionID'] == 'AGE') & (df['ResponseID'] == 'RESP011')]

# %%
sub2.head(30)
# Out:
#          Year Locationabbr Locationdesc         Class Topic  \
# 2051865  2021           AK       Alaska  Demographics   Age
# 2052901  2021           AK       Alaska  Demographics   Age
# 2053061  2021           AK       Alaska  Demographics   Age
# 2053970  2021           AK       Alaska  Demographics   Age
# 2054607  2021           AK       Alaska  Demographics   Age
# 2055560  2021           AK       Alaska  Demographics   Age
# 2055731  2021           AK       Alaska  Demographics   Age
# 2056284  2021           AK       Alaska  Demographics   Age
# 2057389  2021           AK       Alaska  Demographics   Age
# 2058030  2021           AK       Alaska  Demographics   Age
# 2058285  2021           AK       Alaska  Demographics   Age
# 2058648  2021           AK       Alaska  Demographics   Age
# 2059376  2021           AK       Alaska  Demographics   Age
# 2060117  2021           AK       Alaska  Demographics   Age
# 2060754  2021           AK       Alaska  Demographics   Age
# ...

# %%
sub2.Sample_Size = sub2.Sample_Size.astype(int)
# Out:
# C:\Users\theva\anaconda3\lib\site-packages\pandas\core\generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
sub2.groupby('Break_Out_Category')['Sample_Size'].sum()
# Out:
# Break_Out_Category
# Education Attained    667
# Gender                670
# Household Income      550
# Overall               670
# Race/Ethnicity        670
# Name: Sample_Size, dtype: int32

# %% [markdown]
# #### sub3: ResponseID = RESP012

# %%
#Creating a limited group to expore the nature of the break-out variable
#sub2 is records from Ak, 2021, AGE question, RESP011
sub3 = df.loc[(df['Year'] == 2021) & (df['Locationabbr']== 'AK') & (df['QuestionID'] == 'AGE') & (df['ResponseID'] == 'RESP012')]

# %%
sub3.head(30)
# Out:
#          Year Locationabbr Locationdesc         Class Topic  \
# 2052542  2021           AK       Alaska  Demographics   Age
# 2053009  2021           AK       Alaska  Demographics   Age
# 2053172  2021           AK       Alaska  Demographics   Age
# 2053431  2021           AK       Alaska  Demographics   Age
# 2053677  2021           AK       Alaska  Demographics   Age
# 2053959  2021           AK       Alaska  Demographics   Age
# 2054500  2021           AK       Alaska  Demographics   Age
# 2054974  2021           AK       Alaska  Demographics   Age
# 2055802  2021           AK       Alaska  Demographics   Age
# 2057068  2021           AK       Alaska  Demographics   Age
# 2057819  2021           AK       Alaska  Demographics   Age
# 2058364  2021           AK       Alaska  Demographics   Age
# 2058585  2021           AK       Alaska  Demographics   Age
# 2059001  2021           AK       Alaska  Demographics   Age
# 2059807  2021           AK       Alaska  Demographics   Age
# ...

# %%
sub3.Sample_Size = sub3.Sample_Size.astype(int)
# Out:
# C:\Users\theva\anaconda3\lib\site-packages\pandas\core\generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
sub3.groupby('Break_Out_Category')['Sample_Size'].sum()
# Out:
# Break_Out_Category
# Education Attained    776
# Gender                779
# Household Income      666
# Overall               779
# Race/Ethnicity        779
# Name: Sample_Size, dtype: int32

# %% [markdown]
# ### Repeating process with a different state

# %% [markdown]
# #### sub1: ResponseID = RESP010

# %%
#Creating a limited group to expore the nature of the break-out variable
#sub1 is records from Ak, 2021, AGE question, RESP010
sub1 = df.loc[(df['Year'] == 2021) & (df['Locationabbr']== 'CA') & (df['QuestionID'] == 'AGE') & (df['ResponseID'] == 'RESP010')]

# %%
#Examining sub1
sub1.head(30)
# Out:
#          Year Locationabbr Locationdesc         Class Topic  \
# 2065988  2021           CA   California  Demographics   Age
# 2066866  2021           CA   California  Demographics   Age
# 2067663  2021           CA   California  Demographics   Age
# 2069284  2021           CA   California  Demographics   Age
# 2069509  2021           CA   California  Demographics   Age
# 2069571  2021           CA   California  Demographics   Age
# 2071129  2021           CA   California  Demographics   Age
# 2071235  2021           CA   California  Demographics   Age
# 2072332  2021           CA   California  Demographics   Age
# 2073855  2021           CA   California  Demographics   Age
# 2074530  2021           CA   California  Demographics   Age
# 2074648  2021           CA   California  Demographics   Age
# 2075282  2021           CA   California  Demographics   Age
# 2075519  2021           CA   California  Demographics   Age
# 2075635  2021           CA   California  Demographics   Age
# ...

# %%
#Breakout frequency count
sub1['Break_Out'].value_counts().sort_index()
# Out:
# $100,000-$199,999                                          1
# $15,000-$24,999                                            1
# $200,000+                                                  1
# $25,000-$34,999                                            1
# $35,000-$49,999                                            1
# $50,000-$99,999                                            1
# American Indian or Alaskan Native, non-Hispanic            1
# Asian, non-Hispanic                                        1
# Black, non-Hispanic                                        1
# College graduate                                           1
# Female                                                     1
# H.S. or G.E.D.                                             1
# Hispanic                                                   1
# Less than $15,000                                          1
# Less than H.S.                                             1
# ...

# %%
#BreakOutCategoryID frequency count
sub1['Break_Out_Category'].value_counts().sort_index()
# Out:
# Education Attained    4
# Gender                2
# Household Income      7
# Overall               1
# Race/Ethnicity        8
# Name: Break_Out_Category, dtype: int64

# %%
sub1.groupby('Break_Out_Category')['Sample_Size'].value_counts()
# Out:
# Break_Out_Category  Sample_Size
# Education Attained  138            1
#                     207            1
#                     242            1
#                     38             1
# Gender              264            1
#                     364            1
# Household Income    108            1
#                     26             1
#                     65             1
#                     74             1
#                     78             1
#                     83             1
#                     85             1
# Overall             628            1
# Race/Ethnicity      12             1
#                     188            1
#                     23             1
#                     271            1
#                     32             1
#                     5              1
#                     6              1
#                     91             1
# Name: Sample_Size, dtype: int64

# %%
sub1.Sample_Size = sub1.Sample_Size.astype(int)
# Out:
# C:\Users\theva\anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
sub1.groupby('Break_Out_Category')['Sample_Size'].sum()
# Out:
# Break_Out_Category
# Education Attained    625
# Gender                628
# Household Income      519
# Overall               628
# Race/Ethnicity        628
# Name: Sample_Size, dtype: int32

# %% [markdown]
# #### sub2: ResponseID = RESP011

# %%
#Creating a limited group to expore the nature of the break-out variable
#sub2 is records from Ak, 2021, AGE question, RESP011
sub2 = df.loc[(df['Year'] == 2021) & (df['Locationabbr']== 'CA') & (df['QuestionID'] == 'AGE') & (df['ResponseID'] == 'RESP011')]

# %%
sub2.head(30)
# Out:
#          Year Locationabbr Locationdesc         Class Topic  \
# 2065945  2021           CA   California  Demographics   Age
# 2066218  2021           CA   California  Demographics   Age
# 2067398  2021           CA   California  Demographics   Age
# 2068579  2021           CA   California  Demographics   Age
# 2069756  2021           CA   California  Demographics   Age
# 2069876  2021           CA   California  Demographics   Age
# 2069989  2021           CA   California  Demographics   Age
# 2072058  2021           CA   California  Demographics   Age
# 2072459  2021           CA   California  Demographics   Age
# 2072632  2021           CA   California  Demographics   Age
# 2072684  2021           CA   California  Demographics   Age
# 2074023  2021           CA   California  Demographics   Age
# 2074580  2021           CA   California  Demographics   Age
# 2075171  2021           CA   California  Demographics   Age
# 2075428  2021           CA   California  Demographics   Age
# ...

# %%
#Converting comma-separated number objects into integers
# 1. Convert into a string type
sub2.Sample_Size = sub2.Sample_Size.astype(str)

# 2. Use lambda function to remove comma, then turn into an integer
sub2['Sample_Size'] = sub2['Sample_Size'].apply(lambda x: int(str(x).replace(',', '')))
# Out:
# C:\Users\theva\AppData\Local\Temp\ipykernel_2364\4262966908.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub2['Sample_Size'] = sub2['Sample_Size'].apply(lambda x: int(str(x).replace(',', '')))

# %%
sub2.groupby('Break_Out_Category')['Sample_Size'].sum()
# Out:
# Break_Out_Category
# Education Attained    1093
# Gender                1096
# Household Income       948
# Overall               1096
# Race/Ethnicity        1096
# Name: Sample_Size, dtype: int64

# %% [markdown]
# #### sub3: ResponseID = RESP012

# %%
#Creating a limited group to expore the nature of the break-out variable
#sub2 is records from Ak, 2021, AGE question, RESP011
sub3 = df.loc[(df['Year'] == 2021) & (df['Locationabbr']== 'CA') & (df['QuestionID'] == 'AGE') & (df['ResponseID'] == 'RESP012')]

# %%
sub3.head(30)
# Out:
#          Year Locationabbr Locationdesc         Class Topic  \
# 2066251  2021           CA   California  Demographics   Age
# 2067113  2021           CA   California  Demographics   Age
# 2068213  2021           CA   California  Demographics   Age
# 2069001  2021           CA   California  Demographics   Age
# 2069162  2021           CA   California  Demographics   Age
# 2069826  2021           CA   California  Demographics   Age
# 2070579  2021           CA   California  Demographics   Age
# 2071088  2021           CA   California  Demographics   Age
# 2071493  2021           CA   California  Demographics   Age
# 2071942  2021           CA   California  Demographics   Age
# 2073052  2021           CA   California  Demographics   Age
# 2073278  2021           CA   California  Demographics   Age
# 2074015  2021           CA   California  Demographics   Age
# 2074919  2021           CA   California  Demographics   Age
# 2075999  2021           CA   California  Demographics   Age
# ...

# %%
#Converting comma-separated number objects into integers
# 1. Convert into a string type
sub3.Sample_Size = sub3.Sample_Size.astype(str)

# 2. Use lambda function to remove comma, then turn into an integer
sub3['Sample_Size'] = sub3['Sample_Size'].apply(lambda x: int(str(x).replace(',', '')))
# Out:
# C:\Users\theva\AppData\Local\Temp\ipykernel_2364\3445644922.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sub3['Sample_Size'] = sub3['Sample_Size'].apply(lambda x: int(str(x).replace(',', '')))

# %%
sub3.groupby('Break_Out_Category')['Sample_Size'].sum()
# Out:
# Break_Out_Category
# Education Attained    1079
# Gender                1083
# Household Income       953
# Overall               1083
# Race/Ethnicity        1083
# Name: Sample_Size, dtype: int64

# %% [markdown]
# #### Final test

# %% [markdown]
# Conculsion: Each Break_Out_Category has multiple Break_Outs within it, except Overall which just contains itself. The aggregated Sample_Size of Break_Outs_Categories add up to the same as Overall. Education Attained comes out slightly less and Household Income comes out significantly less.</br>
#
# The Break_Out_Categories are likely just subgroups for classification purposes and Overall represents the whole for each Question.
